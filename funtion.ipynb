# %%
def is_even(number):
    """ 
    this funtion tells if a given number is odd or even 
    input :- any valid  intiger
    output :- even/odd
    creat by Dibyendu sasmal
    last edited:- 28/10/2022
    """
    if number%2 == 0:
        return "even"
    else:
        return "odd"
    
for i in range(1,11):
    print(i,"=",is_even(i))
# Out:
# 1 = odd
# 2 = even
# 3 = odd
# 4 = even
# 5 = odd
# 6 = even
# 7 = odd
# 8 = even
# 9 = odd
# 10 = even

# %%
def is_even(number):
    """ 
    this funtion tells if a given number is odd or even 
    input :- any valid  intiger
    output :- even/odd
    creat by Dibyendu sasmal
    last edited:- 28/10/2022
    """
    if type(number) == int:
        
        if number%2 == 0:
            return "even"
        else:
            return "odd"
    else:
        print("not allow ,please enter integer number")

# %%
is_even("heloo")
# Out:
# not allow ,please enter integer number

# %%
is_even(5)
# Out:
# 'odd'

# %%
def is_even(number):
    """ 
    this funtion tells if a given number is odd or even 
    input :- any valid  intiger
    output :- even/odd
    creat by Dibyendu sasmal
    last edited:- 28/10/2022
    """
    if number%2 == 0:
        print("even")
    else:
        print("odd")

# %%
x = is_even(455)
print(x)
# Out:
# odd
# None

# %%
# here return none beacuse when python don't return enything bydefult it"s return none 
# this funtion don't have any return funtion that whay did't return any things 
# that's why they return none

# %%
def imdbr(reting):
    if reting<6 and reting>0:
        if reting >= 5 and reting>3 :
            return "very good movie"
        elif reting>=3 and reting>2:
            return " good movie"

        else:
            return "very bad movies"
    else:
        print("enter valid retting")

# %%
imdbr(7)
# Out:
# enter valid retting

# %%
imdbr(5)
# Out:
# 'very good movie'

# %%
imdbr(1)
# Out:
# 'very bad movies'

# %%
imdbr(3)
# Out:
# ' good move'

# %%
# ddefult argument

# %%
def powerr(a=1,b=1):
    return a**b

# %%
powerr(2,5)
# Out:
# 32

# %%
powerr(5)
# Out:
# 5

# %%
 # positional argument

# %%
# keyword argument

# %%
powerr(b=3,a=2)
# Out:
# 8

# %%
# arbitrary argument

# %%
def flexi(*number):
    product = 1
    print(number)
    print(type(number))
    for i in number:
        product=product*i
    print(product)

# %%
flexi(1,2,3,4,5,6)
# Out:
# (1, 2, 3, 4, 5, 6)
# <class 'tuple'>
# 720

# %%
def f(y):
    x = 1
    x+=1
    print(x)
    
x = 5
f(x)
print(x)
# Out:
# 2
# 5

# %%
def g(y):
    print(x)
    print(x+1)
    
x = 5
g(x)
print(x)
# Out:
# 5
# 6
# 5

# %%
def h(y):
    x+=1
    
x = 5
h(x)
print(x)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Input In [30], in <cell line: 5>()
#       2     x+=1
#       4 x = 5
# ----> 5 h(x)
#       6 print(x)
#
# Input In [30], in h(y)
#       1 def h(y):
# ----> 2     x+=1
#
# UnboundLocalError: local variable 'x' referenced before assignment

# %%
def h(y):
    global x # global variable change nahi karna chahiye
    x+=1
    
x = 5
h(x)
print(x)
# Out:
# 6

# %%
def f(x):
    x=x+1
    print("in f(x): x = ",x)
    return x
x = 3
z = f(x)
print("in main program scope: z = ",z)
print("in main program scope: x = ",x)
# Out:
# in f(x): x =  4
# in main program scope: z =  4
# in main program scope: x =  3

# %% [markdown]
# # nested funtion

# %%
def f():
    print("inside f")
    def g():
        print("inside g")
    g()

# %%
f()
# Out:
# inside f
# inside g

# %%
def f():
    print("inside f")
    def g():
        print("inside g")
        f()
    g()
f()
# this type call make infinite loop
# Out:
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# inside f
# inside g
# ...

# %%
# Out:
# d

# %%
def g(x):
    def h():
        x = "abc"
    x +=1
    print("in g(X): x = ",x)
    h()
    return x
x = 3
z = g(x)
# Out:
# in g(X): x =  4

# %%
# funtion as a object

# %%
def f(num):
    return num**2

# %%
f(5)
# Out:
# 25

# %%
f(2)
# Out:
# 4

# %%
x = f

# %%
x(2)
# Out:
# 4

# %%
x(3)
# Out:
# 9

# %%
del(f)

# %%
f(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 f(2)
#
# NameError: name 'f' is not defined

# %%
x(4)
# Out:
# 16

# %%
type(x)
# Out:
# function

# %%
l = [1,2,3,x]

# %%
l
# Out:
# [1, 2, 3, <function __main__.f(num)>]

# %%
l[-1](3)
# Out:
# 9

# %%
l = [1,2,3,x(4)]

# %%
l
# Out:
# [1, 2, 3, 16]

# %%
def fun_a():
    print("inside the funtion a")
def fun_b(z):
    print("inside the fution b")
    return z()
    
print(fun_b(fun_a))
# Out:
# inside the fution b
# inside the funtion a
# None

# %%
# funtion return

# %%
def f():
    def x(a,b):
        return a+b
    return x

val = f()(3,5)
print(val)
# Out:
# 8
